# %% [markdown]
# # creating a project: student_marks_analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# to load dataset

# %%
df = pd.read_csv("student_marks.csv")
df
# Out:
#    Student_ID   Name  Maths  Science  English  Attendance
# 0           1  Aditi     78       85       72          90
# 1           2  Rohit     65       70       68          85
# 2           3  Sneha     90       92       88          95
# 3           4   Aman     40       55       60          70
# 4           5   Neha     82       78       80          88

# %%
#to Understand the Data

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Maths       5 non-null      int64
#  3   Science     5 non-null      int64
#  4   English     5 non-null      int64
#  5   Attendance  5 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 368.0+ bytes
#        Student_ID     Maths   Science    English  Attendance
# count    5.000000   5.00000   5.00000   5.000000    5.000000
# mean     3.000000  71.00000  76.00000  73.600000   85.600000
# std      1.581139  19.54482  14.30035  10.807405    9.449868
# min      1.000000  40.00000  55.00000  60.000000   70.000000
# 25%      2.000000  65.00000  70.00000  68.000000   85.000000
# 50%      3.000000  78.00000  78.00000  72.000000   88.000000
# 75%      4.000000  82.00000  85.00000  80.000000   90.000000
# ...

# %%
##Data Analysis Tasks

# %%
#1. Calculate Average Marks per Student

# %%
df['Average'] = df[['Maths','Science','English']].mean(axis=1)
df
# Out:
#    Student_ID   Name  Maths  Science  English  Attendance    Average
# 0           1  Aditi     78       85       72          90  78.333333
# 1           2  Rohit     65       70       68          85  67.666667
# 2           3  Sneha     90       92       88          95  90.000000
# 3           4   Aman     40       55       60          70  51.666667
# 4           5   Neha     82       78       80          88  80.000000

# %%
#2. Find Top & Weak Students

# %%
top_student = df.loc[df['Average'].idxmax()]
weak_student = df.loc[df['Average'].idxmin()]

# %%
top_student
# Out:
# Student_ID        3
# Name          Sneha
# Maths            90
# Science          92
# English          88
# Attendance       95
# Average        90.0
# Name: 2, dtype: object

# %%
weak_student
# Out:
# Student_ID            4
# Name               Aman
# Maths                40
# Science              55
# English              60
# Attendance           70
# Average       51.666667
# Name: 3, dtype: object

# %%
#3. Subject-wise Average

# %%
df[['Maths','Science','English']].mean()
# Out:
# Maths      71.0
# Science    76.0
# English    73.6
# dtype: float64

# %%
#4. Pass / Fail Analysis

# %%
df['Result'] = df['Average'].apply(lambda x: 'Pass' if x >= 40 else 'Fail')
df['Result'].value_counts()
# Out:
# Pass    5
# Name: Result, dtype: int64

# %%
##Data Visualization

# %%
#1. Average Marks Bar Chart

# %%
plt.bar(df['Name'], df['Average'])
plt.xlabel("Students")
plt.ylabel("Average Marks")
plt.title("Average Marks of Students")
plt.show()

# %%
#2. Subject-wise Performance

# %%
df[['Maths','Science','English']].mean().plot(kind='bar')
plt.title("Average Marks per Subject")
plt.show()

# %%
#3. Marks Distribution

# %%
plt.hist(df['Average'], bins=5)
plt.title("Marks Distribution")
plt.xlabel("Average Marks")
plt.ylabel("Number of Students")
plt.show()
